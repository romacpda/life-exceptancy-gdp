# %% [markdown]
# # 🌍 Life Expectancy & GDP (2000–2015)
# ## Analyzing Global Trends in Health and Wealth
# .

# %% [markdown]
# ## 📌 Project Scope & Goals
#
# This project investigates the relationship between **GDP** and **life expectancy** in six countries using data from the World Bank and WHO between 2000–2015.
#
# ### 🌟 Goals:
# - Analyze how GDP and life expectancy evolved over time.
# - Understand differences in growth patterns across countries.
# - Explore how economic indicators might relate to health outcomes.
#
# ### 🧩 Countries in Focus:
# Chile, China, Germany, Mexico, United States
#
# ## ❓ Key Questions
#
# 1. How has **life expectancy** changed from 2000 to 2015 in each country?
# 2. How has **GDP** changed over time in the same period?
# 3. Is there a **correlation between GDP and life expectancy** overall?
# 4. Do **low-income countries** (like Zimbabwe) show stronger improvements in health relative to GDP growth?
# 5. How do **developed vs developing countries** differ in their patterns?
# 6. Which country showed the **most rapid increase in life expectancy**?
# 7. Which country had the **largest economic expansion**?
# 8. Are **increases in GDP associated with proportional improvements** in life expe## 🛠 Tools & Skills Used
#
# - **Libraries**: Pandas, Matplotlib, Seaborn
# - **Techniques**:
#   - Data cleaning & transformation
#   - Exploratory data analysis (EDA)
#   - Statistical correlation
#   - Visualization best practices
# ctancy?
# , Zimbabwe
# is formation and testing

# %% [markdown]
# ## Data Import & Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")

# %%
# Load your dataset
df = pd.read_csv("all_data.csv")

# Quick look
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.info()
df.describe()
df.columns
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# Country                             0
# Year                                0
# Life expectancy at birth (years)    0
# GDP                                 0
# dtype: int64

# %%
df = df.rename(columns={
    'Life expectancy at birth (years)': 'Life_Expectancy'
})

# %% [markdown]
# ## 🔍 Exploratory Data Analysis (EDA)
#
# In this section, we visually explore trends and patterns in the data to begin answering the project’s key questions.

# %% [markdown]
# ### 1. How has life expectancy changed from 2000 to 2015 in each country?
#
# This line plot shows how average life expectancy at birth has changed across six countries.
#
# - Most countries began around 72–78 years and saw gradual increases.
# - **Zimbabwe** stands out with a sharp rise from ~45 to 60 years, starting in 2005.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Life_Expectancy', hue='Country', marker='o')
plt.title('Life Expectancy Over Time (2000–2015)')
plt.ylabel('Life Expectancy (Years)')
plt.xlabel('Year')
plt.legend(title='Country')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\romac\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\romac\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 2. How has GDP changed from 2000 to 2015?
#
# This plot highlights how the economic power of each country shifted.
#
# - The **United States** has the highest GDP overall, with a steady increase.
# - **China** displays the fastest relative growth: a 10x jump.
# - **Zimbabwe, Mexico, and Chile** saw more modest GDP changes.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='GDP', hue='Country', marker='o')
plt.title('GDP Over Time (2000–2015)')
plt.ylabel('GDP (USD)')
plt.xlabel('Year')
plt.legend(title='Country')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\romac\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\romac\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 3. Is there a visible relationship between GDP and life expectancy?
#
# This scatterplot explores the connection between economic output and health.
#
# - A **positive correlation** is visually clear.
# - **Zimbabwe** shows steep health gains from low GDP.
# - **China** shows wider GDP growth with moderate life expectancy increases.
# - **Mexico and Chile** follow tighter, more linear paths.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='GDP', y='Life_Expectancy', hue='Country')
plt.title('GDP vs Life Expectancy')
plt.xlabel('GDP (USD)')
plt.ylabel('Life Expectancy (Years)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🧪 Hypothesis Testing: GDP vs Life Expectancy
#
# **Null Hypothesis (H₀):** There is no correlation between GDP and life expectancy.
# **Alternative Hypothesis (H₁):** There is a positive correlation between GDP and life expectancy.

# %%
correlation = df['GDP'].corr(df['Life_Expectancy'])
print(f"Correlation between GDP and Life Expectancy: {correlation:.2f}")
# Out:
# Correlation between GDP and Life Expectancy: 0.34

# %%
import seaborn as sns

sns.lmplot(data=df, x='GDP', y='Life_Expectancy', hue='Country', height=6, aspect=1.5)
plt.title("Linear Relationship: GDP vs Life Expectancy")
plt.xlabel("GDP (USD)")
plt.ylabel("Life Expectancy (Years)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🧠 Interpretation of Correlation
#
# The correlation coefficient between **GDP** and **Life Expectancy** is **0.34**, indicating a **moderate positive relationship**.
#
# This suggests that, across the six countries studied:
# - As GDP increases, life expectancy *tends* to rise as well.
# - However, the relationship is **not strongly linear**, meaning other factors (like healthcare access, government policy, education, or social stability) may also have a significant impact on life expectancy.
#
# 🔍 Countries like **Zimbabwe** likely drive this weaker correlation:
# - Life expectancy increased dramatically despite relatively low GDP.

# %%
country_corr = df.groupby('Country').apply(
    lambda x: x['GDP'].corr(x['Life_Expectancy'])
).reset_index(name='GDP_LifeExp_Correlation')

print(country_corr)
# Out:
#                     Country  GDP_LifeExp_Correlation
# 0                     Chile                 0.949877
# 1                     China                 0.908526
# 2                   Germany                 0.932699
# 3                    Mexico                 0.932238
# 4  United States of America                 0.981709
# 5                  Zimbabwe                 0.966200

# %% [markdown]
# ### 📊 Correlation Between GDP and Life Expectancy (Per Country)
#
# | Country                 | Correlation |
# |------------------------|-------------|
# | Chile                  | 0.95        |
# | China                  | 0.91        |
# | Germany                | 0.93        |
# | Mexico                 | 0.93        |
# | United States of America | 0.98     |
# | Zimbabwe               | 0.97        |
#
# These findings show a **consistently strong positive correlation** within each country. This means that, while the overall correlation across all countries was only moderate (0.34), each country individually demonstrates that **as GDP increases, life expectancy reliably improves**.
#
# 💡 **Key Insight:**
# The weaker overall correlation

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Define X and y
X = df[['GDP']].values  # 2D array for sklearn
y = df['Life_Expectancy'].values

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Get R² score
r_squared = model.score(X, y)
print(f"R² (Coefficient of Determination): {r_squared:.2f}")
# Out:
# R² (Coefficient of Determination): 0.12

# %% [markdown]
# ### 🧪 Linear Regression Model: GDP Predicting Life Expectancy (All Countries Combined)
#
# We trained a linear regression model with **GDP** as the independent variable and **life expectancy** as the dependent variable across all six countries (2000–2015).
#
# **R² Score:** `0.12`
#
# This means that **only 12%** of the variance in life expectancy can be explained by GDP when looking at all countries together.
#
# 🔍 **Interpretation:**
# - The weak R² confirms that GDP alone does not strongly predict life expectancy when countries are compared globally.
# - This is consistent with our earlier finding that the overall correlation was moderate (0.34).
# - It reinforces the importance of analyzing countries **individually**, where we saw R² values (via correlation) as high as **0.98**.
#
# ➡️ **Conclusion:**
# While GDP tends to increase alongside life expectancy, its predictive power is more meaningful **within countries** than **across them**—highlighting the impact of other country-specific factors like healthcare systems, education, conflict, and policy.

# %% [markdown]
# ## 📌 Project Conclusion
#
# This analysis explored the relationship between **GDP** and **life expectancy** across six countries—Chile, China, Germany, Mexico, United States, and Zimbabwe—using data from the World Health Organization and the World Bank (2000–2015).
#
# ### 🔍 Key Findings:
#
# - **Life Expectancy Trends:**
#   - All countries showed increases in life expectancy over time.
#   - **Zimbabwe** experienced the most dramatic rise—from ~45 years in 2000 to ~60 by 2015—reflecting major public health recovery.
#   - Other countries experienced more gradual growth, starting around 72–78 years and rising to 75–82 years.
#
# - **GDP Growth:**
#   - **China** showed the most rapid economic growth (10x increase), while the **United States** maintained the highest overall GDP.
#   - Countries like **Chile**, **Mexico**, and **Zimbabwe** had more modest or steady increases.
#
# - **GDP vs Life Expectancy (All Countries):**
#   - The overall correlation was **moderate (0.34)**.
#   - A linear regression across all countries yielded an **R² of 0.12**, indicating weak predictive power of GDP alone.
#
# - **GDP vs Life Expectancy (Per Country):**
#   - When analyzed individually, each country showed a **very strong positive correlation** (0.91–0.98) between GDP and life expectancy.
#   - This shows that GDP is a much more powerful predictor **within** countries than **across** them.
#
# ### 🧠 Insights:
#
# - GDP is **not a reliable global predictor** of life expectancy on its own.
# - However, **within individual countries**, improvements in GDP are **consistently associated** with longer life expectancy.
# - Global health outcomes are shaped by more than economic indicators—education, healthcare access, social policies, and historical context all matter.
#
# ---
#
# ### 📈 Next Steps (Optional for Future Exploration):
#
# - Add additional variables (e.g., education levels, healthcare access) to improve model accuracy.
# - Explore non-linear relationships using polynomial regression.
# - Compare developing vs developed nations using grouped models or dashboards.
#
# ---
#
# ### ✅ Final Takeaway:
#
# > Economic growth matters—but when it comes to human health and longevity, it’s only one part of the story.
